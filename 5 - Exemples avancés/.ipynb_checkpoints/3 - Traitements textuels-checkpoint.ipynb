# %% [markdown]
# # Analyse de contenu textuel
#
# Traitement du texte -> TAL
#
# Installer les bibliothèques manquantes

# %% [markdown]
# ### Chargement du corpus

# %%
import pandas as pd
corpus = pd.read_csv("../Data/europresse_science_ouverte_presse_nationale.csv")
corpus.head()
# Out:
#     Date_reco                                               Date  \
# 0  2021-07-15   Science & Médecine,  jeudi 15 juillet 2021 72...
# 1  2021-12-11        Régions,  samedi 11 décembre 2021 597 mots
# 2  2020-06-16              mardi 16 juin 2020 1026 mots, p. 8,9
# 3  2020-01-10   Horizons,  vendredi 10 janvier 2020 1873 mots...
# 4  2017-09-20   Science & Médecine,  mercredi 20 septembre 20...
#
#                                                Titre  \
# 0   Des résultats scientifiques plus accessibles ...
# 1   In&Sight, la plateforme bordelaise résolue à ...
# 2   Coronavirus : les grandes revues scientifique...
# 3   Paul Allen, bienfaiteur de Seattle La philant...
# 4   La recherche académique a tout à gagner à se ...
#
#                              Journal  \
# 0                        Le Monde
# 1   La Tribune (France), no. 7287
# 2                      Libération
# 3                        Le Monde
# 4                        Le Monde
#
#                                              Contenu  \
# 0    Les budgets qui augmentent dans le monde de ...
# 1    LA TRIBUNE - Vous avez co-fondé In&Sight (1)...
# 2    Al'image du Lancet, les revues scientifiques...
# 3    Seattle (États-Unis) envoyé spécial - Le cél...
# 4    Progressivement, le concept d'Open Science t...
#
#                                  Auteur
# 0                     David Larousserie
# 1  Propos recueillis par Anne Farthouat
# 2                         Olivier Monod
# 3                   Arnaud Leparmentier
# 4                                   NaN

# %% [markdown]
# ## Utiliser des traitements statistiques
#
# Texte -> vecteur -> traitements statistiques
#
# Le mot (ou le lemme) comme unité de base, puis des méthodes génériques
#
# (par ex ici : https://towardsdatascience.com/clustering-documents-with-python-97314ad6a78d)

# %%
# Utilisation de sklearn (mais possible d'utiliser d'autres bibliothèques)
from sklearn.feature_extraction.text import TfidfVectorizer

# Création d'un objet de vectorisation
vectorizer = TfidfVectorizer(stop_words={'french'})

# Application
X = vectorizer.fit_transform(corpus["Contenu"])

# %%
vectorizer.get_feature_names()[10000:10010]
# Out:
# /home/emilien/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['monture',
#  'monté',
#  'montée',
#  'montés',
#  'monumentale',
#  'monétaire',
#  'monétaires',
#  'monétaristes',
#  'monétise',
#  'monétisent']

# %%
X[1,:].todense()
# Out:
# matrix([[0.02261373, 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ]])

# %% [markdown]
# Une fois la matrice obtenue, il est possible d'appliquer une méthode numérique de clusters
#
# (ici la méthode des K-means : trouver les N groupes qui minimisent la distance suivant certaines règles

# %% [markdown]
# On teste plusieurs N pour trouver celui qui marche le mieux ...

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


Sum_of_squared_distances = []
K = range(2,30)
for k in K:
    km = KMeans(n_clusters=k, max_iter=200, n_init=10)
    km = km.fit(X)
    Sum_of_squared_distances.append(km.inertia_)
    
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
# Out:
# Text(0, 0.5, 'Sum_of_squared_distances')

# %% [markdown]
# Application d'un clustering

# %%
true_k = 10
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=200, n_init=10)
model.fit(X)
corpus["labels"] = model.labels_

# %%
corpus[corpus["labels"]==2]
# Out:
#       Date_reco                                               Date  \
# 1    2021-12-11        Régions,  samedi 11 décembre 2021 597 mots
# 12   2020-12-12   Culture,  samedi 12 décembre 2020 1309 mots, ...
# 13   2020-10-15            jeudi 15 octobre 2020 2310 mots, p. 12
# 27   2016-09-23   Opinions,  vendredi 23 septembre 2016 756 mot...
# 28   2022-02-16   Science & Médecine,  mercredi 16 février 2022...
# 34   2020-03-31   Idées & Débats,  mardi 31 mars 2020 603 mots,...
# 36   2020-05-30               samedi 30 mai 2020 763 mots, p. 4,5
# 42   2020-02-12   Science & Médecine,  mercredi 12 février 2020...
# 44   2002-05-22              mercredi 22 mai 2002 788 mots, p. 12
# 45   2021-02-01   Idées & Débats,  lundi 1 février 2021 1326 mo...
# 47   2020-09-07   Idées & Débats,  lundi 7 septembre 2020 371 m...
# 51   2020-07-06   Idées & Débats,  lundi 6 juillet 2020 1329 mo...
# 58   2006-09-19   SCIENCES,  mardi 19 septembre 2006 70 mots, p...
# 60   2014-01-10   Monde des livres,  vendredi 10 janvier 2014 4...
# 62   2014-04-04   Sciences,  vendredi 4 avril 2014 909 mots, p....
# 71   2012-03-05    Innovation,  lundi 5 mars 2012 414 mots, p. 10
# 73   2012-02-04   Science & techno,  samedi 4 février 2012 514 ...
# 77   2000-12-07   La vie des idées,  jeudi 7 décembre 2000 782 ...
# 78   2003-06-11   Economie,  mercredi 11 juin 2003 418 mots, p. 6
# 81   2016-10-26   Science & techno,  mercredi 26 octobre 2016 1...
# 83   2016-11-02   Science & techno,  mercredi 2 novembre 2016 1...
# 84   2016-07-06   Science & techno,  mercredi 6 juillet 2016 64...
# 86   2016-03-07     Le Figaro,  lundi 7 mars 2016 499 mots, p. 12
# 90   2021-07-07   Science & Médecine,  mercredi 7 juillet 2021 ...
# 95   2017-11-03   Le Monde des Livres,  vendredi 3 novembre 201...
# 108  2019-01-09   Science & Médecine,  mercredi 9 janvier 2019 ...
# 118  2001-07-30   SOCIETE,  lundi 30 juillet 2001 417 mots, p. 13
# 121  2001-09-05   SUPPLEMENT INDUSTRIE,  mercredi 5 septembre 2...
# 127  2004-05-18        Agenda,  mardi 18 mai 2004 664 mots, p. 27
# 132  2003-06-10        Idées,  mardi 10 juin 2003 469 mots, p. 22
# 134  2010-06-29   Sciences et éthique,  mardi 29 juin 2010 411 ...
# 136  1996-07-11     LIVRES,  jeudi 11 juillet 1996 388 mots, p. 7
# 137  2002-12-12   ECONOMIE,  jeudi 12 décembre 2002 595 mots, p...
# 140  2003-07-08      Idées,  mardi 8 juillet 2003 369 mots, p. 23
# 149  2008-09-12   Monde des livres,  vendredi 12 septembre 2008...
# 164  2009-05-15   Monde des livres,  vendredi 15 mai 2009 366 m...
# 177  2018-09-29   Le Figaro,  samedi 29 septembre 2018 199 mots...
# 179  2018-06-13   Science & Médecine,  mercredi 13 juin 2018 19...
# 136    Pour le vulgum pecus, c'est-à-dire le Nous m...
# 137    Ce serait une petite révolution culturelle. ...
# 140    Une histoire naturelle de la séduction , de ...
# 149    Charles Darwin a toujours le dos aussi large...
# 164    ROBERT FitzRoy (1805-1865) croyait passionné...
# 177    Premier cas humain d'hépatite E du rat Un ha...
# 179    Accolée au grand bassin de Nausicaa, une sal...
# 180    Un cursus emballant, des méthodes pédagogiqu...
# 182    Que ce soit au cinéma, au théâtre, dans les ...
# 184    Le braconnage est la principale menace pour ...
# 185    ENTOMOLOGIE  C'est un peu l'histoire de l'ar...
# 187    Vous reconnaissez votre ami par le langage q...
# 189    Montre connectée pour mesurer l'activité phy...
# 190    Ces derniers mois, plusieurs rapports ont fa...
# 191    Les peintures ornant la grotte de Lascaux da...
#
#                                                 Auteur  labels
# 1                 Propos recueillis par Anne Farthouat       2
# 12                  Propos recueillis par Piotr Smolar       2
# 13                                                 NaN       2
# 27                   Céline Soulas et Christine Sinapi       2
# 28   propos recueillis parDavid Larousserie propos ...       2
# 34                                      GILLES BABINET       2
# 36                                 Recueilli par O.Mo.       2
# 42                                                 NaN       2
# 44                                     Marc MENNESSIER       2
# 45                                          YANN VERDO       2
# 47                                          YANN VERDO       2
# 51                                          YANN VERDO       2
# 58                                      HUET Sylvestre       2
# 60                                                 NaN       2
# 62                                      Sylvestre Huet       2
# 71                                         ALAIN PEREZ       2
# 73                                               H. M.       2
# 77                                       Degoy, Lucien       2
# 78                                 par Philippe Arnaud       2
# 81                                       Sabah Rahmani       2
# 83                                       Sabah Rahmani       2
# 84                                   David Larousserie       2
# 86                                   Nothias, Jean-Luc       2
# 90                                  Nathaniel Herzberg       2
# 95                                     Franck Johannès       2
# 108                                                NaN       2
# 118                                    FRANKEL Charles       2
# 121                                  Ducruet Catherine       2
# 127                                  Catherine Vincent       2
# 132                        Nielsberg, Jérôme-Alexandre       2
# 134                                     LANG Dominique       2
# 136                                      SMITH Stephen       2
# 137  BISEAU Grégoire, LATRIVE Florent, MAUSSION Cat...       2
# 140                                   Dupouey, Patrick       2
# 149                                   Stéphane Foucart       2
# 164                                   Stéphane Foucart       2
# 177                                  Nothias, Jean-Luc       2
# 179                                                NaN       2
# 180                                                NaN       2
# 182                                  Pierre Barthélémy       2
# 184                                                NaN       2
# 185                                  Nothias, Jean-Luc       2
# 187                                 par Paul Seabright       2
# 189  Propos recueillis par Laure Belot Propos recue...       2
# 190                                                NaN       2
# 191                                         YANN VERDO       2

# %% [markdown]
# ## Utiliser une bibliothèque de TAL
#
# SpaCy est assez mature
#
# Si ça vous intéresse : https://www.youtube.com/c/PythonTutorialsforDigitalHumanities/playlists?view=50&sort=dd&shelf_id=4

# %% [markdown]
# ![blob](https://spacy.io/pipeline-fde48da9b43661abcdf62ab70a546d71.svg)

# %%
# Installer spacy et les modèles
#pip install spacy
# https://spacy.io/models/fr -> installer le modèle
#!python -m spacy download fr_core_news_md #sm

import spacy

nlp = spacy.load("fr_core_news_md")

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x146815000>),
#  ('morphologizer',
#   <spacy.pipeline.morphologizer.Morphologizer at 0x1468159c0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x14633d700>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x1460e8d00>),
#  ('lemmatizer', <spacy.lang.fr.lemmatizer.FrenchLemmatizer at 0x1460eb7c0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x14633d8c0>)]

# %% [markdown]
# Test sur une phrase

# %%
phrase_enveloppee = nlp("Tester ceci sur une phrase. Est-ce que cela va marcher ?")

# %%
for i in phrase_enveloppee:
    print(i,i.pos_)
# Out:
# Tester VERB
# ceci PRON
# sur ADP
# une DET
# phrase NOUN
# . PUNCT
# Est NOUN
# -ce PRON
# que SCONJ
# cela PRON
# va VERB
# marcher VERB
# ? PUNCT

# %%
phrase_enveloppee.ents
# Out:
# ()

# %% [markdown]
# Application sur le corpus

# %%
corpus["Spacy"] = corpus["Contenu"].apply(nlp)

# %% [markdown]
# Détection d'entités

# %%
corpus["Spacy"].iloc[3].ents
# Out:
# (MONDE,
#  Nivaquine,
#  Chine,
#  Plaquenil,
#  SARS-CoV-2,
#  France,
#  Didier Raoult,
#  Institut hospitalo-universitaire,
#  Méditerranée,
#  Marseille,
#  ministre de la Santé,
#  Plaquenil,
#  Allemagne,
#  SARS,
#  Chine,
#  Cell Research,
#  Chine,
#  BioScience,
#  Zhong Nanshan,
#  SARS,
#  Chinois,
#  Didier Raoult,
#  CPP,
#  Agence nationale de sécurité du médicament et des produits de santé,
#  ANSM,
#  Raoult,
#  Pour ce spécialiste des maladies infectieuses,
#  Covid-19,
#  Chine,
#  Iran,
#  Corée du Sud,
#  Arabie saoudite,
#  France,
#  CRPV,
#  Covid-19,
#  Covid-19,
#  Sanofi,
#  Dépakine,
#  Nivaquine,
#  Le Monde,
#  Chine,
#  Iran,
#  Corée du Sud,
#  Arabie saoudite,
#  DIRECTEUR DE,
#  MARSEILLE)

# %% [markdown]
# Ne garder que les noms mentionnés dans l'article

# %%
def filter_words(x):
    r = []
    for token in x:
        if token.pos_ == "NOUN":
            r.append(token.lemma_)
    return r

# %%
corpus["BOW"] = corpus["Spacy"].apply(filter_words)

# %%
corpus["BOW"].iloc[10]
# Out:
# ['chercheur',
#  'mort',
#  'étude',
#  'chloroquine',
#  'polémique',
#  'cible',
#  'uneviolente',
#  'scientifique',
#  'romand',
#  'tribunedan',
#  'plainte',
#  'science',
#  'controverse',
#  'dispute',
#  'violence',
#  'étude',
#  'inutilité',
#  'dangerosité',
#  'chloroquine',
#  'coronavirus',
#  'chercheur',
#  'université',
#  'objet',
#  'campagne',
#  'raillerie',
#  'intimidation',
#  'insulte',
#  'homophobe',
#  'menace',
#  'mort',
#  'cabale',
#  'prochloroquine',
#  'publication',
#  'étude',
#  'revue',
#  'infection',
#  'fin',
#  'août',
#  'centaine',
#  'message',
#  'insulte',
#  'menace',
#  'coup',
#  'téléphone',
#  'parent',
#  'biochimie',
#  'collègue',
#  'droit',
#  'salve',
#  'acabit',
#  'appel',
#  'assassin',
#  'humanité',
#  'pharma',
#  'rue',
#  'vidéo',
#  'soutien',
#  'confrère',
#  'période',
#  'peur',
#  'téléphone',
#  'saisie',
#  'traitement',
#  'mois',
#  'débat',
#  'médicament',
#  'voisin',
#  'impulsion',
#  'professeur',
#  'chantre',
#  'molécule',
#  'ordre',
#  'médecin',
#  'partisan',
#  'opposant',
#  'traitement',
#  'mois',
#  'chercheur',
#  'assaillant',
#  'majorité',
#  'attaque',
#  'sud',
#  'hôpital',
#  'attaque',
#  'droit',
#  'insulte',
#  'liaison',
#  'confrère',
#  'injure',
#  'téléphone',
#  'mort',
#  'groupe',
#  'centaine',
#  'millier',
#  'personne',
#  'réseau',
#  'numéro',
#  'téléphone',
#  'adresse',
#  'internaute',
#  'chercheur',
#  'dossier',
#  'page',
#  'fichier',
#  'main',
#  'justice',
#  'plainte',
#  'cyberharcèlement',
#  'épidémiologiste',
#  'origine',
#  'étude',
#  'justice',
#  'marge',
#  'démarche',
#  'chercheur',
#  'tribune',
#  'revue',
#  'vendredi',
#  'conte',
#  'populisme',
#  'obscurantisme',
#  'texte',
#  'message',
#  'campagne',
#  'chercheur',
#  'période',
#  'doute',
#  'crainte',
#  'monde',
#  'information',
#  'option',
#  'recherche',
#  'plainte',
#  'cyber',
#  'stade',
#  'plainte',
#  'service',
#  'université',
#  'suite',
#  'lâche',
#  'm',
#  'fin',
#  'affaire',
#  'conseille',
#  'position',
#  'police',
#  'personne',
#  'infraction',
#  'harcèlement',
#  'ligne',
#  'cas',
#  'police',
#  'plainte',
#  'auteur',
#  'justice',
#  'victime',
#  'police',
#  'travail',
#  'enquête',
#  'contenu',
#  'hébergeur',
#  'plateforme',
#  'dépôt',
#  'plainte',
#  'étendue',
#  'pratique',
#  'web',
#  'plainte',
#  'genre',
#  'janvier',
#  'infraction',
#  'cyberharcèlement',
#  'droit',
#  'force',
#  'ordre',
#  'face',
#  'police',
#  'brigade',
#  'domaine',
#  'cyber',
#  'enquêteur',
#  'spécialiste',
#  'acte',
#  'connaissance',
#  'élément',
#  'preuve',
#  'victime',
#  'capture',
#  'écran',
#  'photo',
#  'échange',
#  'mail',
#  'chat',
#  'insulte',
#  'menace',
#  'auteur',
#  'agissement',
#  'fait',
#  'auteur',
#  'justice']

# %% [markdown]
# Et ensuite ... construire des modèles :)

# %%
a = corpus["Spacy"].loc[10]

# %%
corpus["Spacy"].apply(lambda x : x.similarity(a))
# Out:
# 0      0.976567
# 1      0.978755
# 2      0.918640
# 3      0.936945
# 4      0.953656
#          ...
# 232    0.961570
# 233    0.964838
# 234    0.965946
# 235   -0.064989
# 236    0.962488
# Name: Spacy, Length: 237, dtype: float64
